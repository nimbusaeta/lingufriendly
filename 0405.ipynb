# %% [markdown]
# # Ejercicio final del tema 4 - Red social
# En temas anteriores, el usuario no tenía ninguna capacidad de decisión. Solo iba respondiendo a lo que el programa le pedía. Ahora vamos a dejarle tomar pequeñas decisiones, implantando un sencillo menú.
#
# Modifica el programa anterior de forma que:
# - Al principio del todo, le pregunte al usuario si quiere crear un perfil nuevo o no. El usuario debe poder contestar a esta pregunta con variantes de `sí` y de `no`, como `s`, `SÍ`, `sip`, `YES`, etc. Basta con que pongas dos para cada respuesta posible, pero puedes dejar volar tu imaginación.
#     - Si quiere crearlo, usaremos el código que ya tenemos escrito en el ejercicio del tema 3 para pedirle sus datos e imprimirlos por pantalla, diciendo `Tu perfil ha sido creado`. Pero nada más; ya no le pediremos un mensaje de estado después.
#     - Si el usuario no quiere crear un perfil nuevo, mostraremos entonces un menú con 3 opciones, dándole a entender que si escribe `1` elige la primera opción, si escribe `2` la segunda, etcétera. Las opciones serán:
#         - Crear un perfil nuevo: en este caso, reutilizaremos el código con el que le pedíamos sus datos y los imprimíamos por pantalla, diciendo `Tu perfil ha sido creado`.
#         - Modificar sus datos: para este caso, también reutilizaremos el código con el que le pedíamos sus datos y los imprimíamos por pantalla, pero esta vez diremos `Tu perfil ha sido actualizado`.
#         - Publicar un mensaje: en este caso, usaremos el código que habíamos escrito para preguntarle qué quiere publicar e imprimirlo por pantalla.
#
# Aquí tienes 4 ejemplos de cómo debería quedar el programa, según lo que haya decidido hacer el usuario:
#
# Ejemplo 1 - El usuario crea un perfil
#
#     ¿Quieres crear un perfil nuevo? (responde sí o no): s
#     ¿Cómo te llamas?: Gustavo Adolfo Claudio
#     ¿Cuál es tu primer apellido?: DOMÍNGUEZ
#     ¿Y el segundo?: BASTIDA
#     ¿Cuál es tu año de nacimiento?: 1836
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 178
#
#     Tu perfil ha sido creado.
#     Nombre: Gustavo Adolfo Claudio Domínguez Bastida
#     Edad: 183 años
#     Estatura: 1.78 metros
#
# Ejemplo 2 - El usuario no crea un perfil nuevo, pero tras ver el menú decide crearlo
#
#     ¿Quieres crear un perfil nuevo? (responde sí o no): nop
#     Elige una de las opciones que se detallan a continuación:
#
#     Menú
#     1. Rellenar perfil de usuario
#     2. Modificar mis datos
#     3. Publicar un mensaje de estado
#     1
#     ¿Cómo te llamas?: Gustavo Adolfo Claudio
#     ¿Cuál es tu primer apellido?: DOMÍNGUEZ
#     ¿Y el segundo?: BASTIDA
#     ¿Cuál es tu año de nacimiento?: 1836
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 178
#
#     Tu perfil ha sido creado.
#     Nombre: Gustavo Adolfo Claudio Domínguez Bastida
#     Edad: 183 años
#     Estatura: 1.78 metros
#
# Ejemplo 3 - El usuario no crea un perfil, pero tras ver el menú decide actualizar sus datos
#
#     ¿Quieres crear un perfil nuevo? (responde sí o no): nein
#     Elige una de las opciones que se detallan a continuación:
#
#     Menú
#     1. Rellenar perfil de usuario
#     2. Modificar mis datos
#     3. Publicar un mensaje de estado
#     2
#     ¿Cómo te llamas?: Gustavo Adolfo Claudio
#     ¿Cuál es tu primer apellido?: DOMÍNGUEZ
#     ¿Y el segundo?: BASTIDA
#     ¿Cuál es tu año de nacimiento?: 1836
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 178
#
#     Tu perfil ha sido actualizado.
#     Nombre: Gustavo Adolfo Claudio Domínguez Bastida
#     Edad: 183 años
#     Estatura: 1.78 metros
#
# Ejemplo 4 - El usuario no crea un perfil, y tras ver el menú decide publicar un mensaje
#
#     ¿Quieres crear un perfil nuevo? (responde sí o no): NO
#     Elige una de las opciones que se detallan a continuación:
#
#     Menú
#     1. Rellenar perfil de usuario
#     2. Modificar mis datos
#     3. Publicar un mensaje de estado
#     3
#     ¿Qué estás pensando?: Por una mirada, un mundo; por una sonrisa, un cielo; por un beso... ¡Yo no sé qué te diera por un beso!
#
#     El usuario dice: Por una mirada, un mundo; por una sonrisa, un cielo; por un beso... ¡Yo no sé qué te diera por un beso!
#
# Recuerda que el código que envíes debe poder satisfacer todas estas necesidades del usuario. También es importante que mantengas tu programa bien documentado; ya empieza a volverse un poco largo, así que como ves cada vez es más crítico para saber en qué parte del programa estamos.
