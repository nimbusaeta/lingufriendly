# %% [markdown]
# # Ejercicio final del tema 6 - Red social
# Hasta ahora, toda la información del perfil del usuario venía de su parte, directamente o a través de cálculos que hacíamos con información aportada por él.
#
# En este ejercicio vamos a completar la información de perfil con datos que obtenemos de otras fuentes.
#
# Modifica el programa del tema anterior para que esta vez:
# - Pregunte, cada vez que el usuario quiera rellenar o actualizar sus datos, por la provincia en la que vive y la transforme a todo minúsculas, para que pueda escribirla como quiera.
# - Imprima, con las iniciales mayúsculas, el dato de la provincia en la parte que imprime los datos del usuario.
# - Compruebe si la provincia introducida por el usuario está en el diccionario de provincias que se proporciona más abajo. Fíjate en que las claves son strings y los valores son listas, de modo que tendrás que recorrer el diccionario con un `for`.
#     - Si está, debe imprimirse el dato de la comunidad autónoma a la que pertenece.

# %% [markdown]
# Aquí tienes los datos de las comunidades autónomas que necesitas para España, pero puedes hacerlo con cualquier país. Fíjate en que las provincias están dadas en minúsculas para que puedas compararlas con lo que ponga el usuario transformado a minúsculas; de esta forma, el usuario puede introducir la provincia de cualquier forma, mientras las tildes estén bien puestas.

# %%
# Diccionario de provincias españolas por comunidad autónoma

provincias = {
    "Andalucía": [
        "almería",
        "cádiz",
        "córdoba",
        "granada",
        "huelva",
        "jaén",
        "málaga",
        "sevilla"
    ],
    "Aragón": [
        "huesca",
        "zaragoza",
        "teruel"
    ],
    "Asturias": ["asturias"],
    "Cantabria": ["cantabria"],
    "Castilla-La Mancha": [
        "albacete",
        "ciudad real",
        "cuenca",
        "guadalajara",
        "toledo"
    ],
    "Castilla y León": [
        "ávila",
        "burgos",
        "león",
        "palencia",
        "salamanca",
        "segovia",
        "soria",
        "valladolid",
        "zamora"
    ],
    "Cataluña": [
        "barcelona",
        "girona",
        "lleida",
        "tarragona"],
    "Comunidad de Madrid": ["madrid"],
    "Comunidad Valenciana": [
        "alicante",
        "castellón",
        "valencia"
    ],
    "Extremadura": [
        "badajoz",
        "cáceres"
    ],
    "Galicia": [
        "a coruña",
        "lugo",
        "ourense",
        "pontevedra"
    ],
    "Islas Baleares": ["islas baleares"],
    "Islas Canarias": [
        "santa cruz de tenerife",
        "las palmas"
    ],
    "La Rioja": ["la rioja"],
    "Navarra": ["navarra"],
    "País Vasco": [
        "álava",
        "guipúzcoa",
        "vizcaya"
    ],
    "Región de Murcia": ["murcia"]
}

# %% [markdown]
# Este es el output esperado para el ejercicio:
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Publicar un mensaje de estado
#         4. Salir
#
#         Elige tu opción: 1
#     ¿Cómo te llamas?: JUANA
#     ¿Cuál es tu primer apellido?: asbaje
#     ¿Y el segundo?: ramírez
#     ¿Cuál es tu año de nacimiento?: 1648
#     ¿En qué provincia vives?: logroño
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 161
#
#     Tu perfil ha sido creado.
#
#     Nombre: Juana Asbaje Ramírez
#     Edad: 374 años
#     Provincia: Logroño
#     Comunidad: La Rioja
#     Estatura: 1.61 metros
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Publicar un mensaje de estado
#         4. Salir
#
#         Elige tu opción: 2
#     ¿Cómo te llamas?: JUANA
#     ¿Cuál es tu primer apellido?: asbaje
#     ¿Y el segundo?: ramírez
#     ¿Cuál es tu año de nacimiento?: 1648
#     ¿En qué provincia vives?: Tepetlixpa
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 161
#
#     Tu perfil ha sido actualizado.
#
#     Nombre: Juana Asbaje Ramírez
#     Edad: 374 años
#     Provincia: Tepetlixpa
#     Estatura: 1.61 metros
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Publicar un mensaje de estado
#         4. Salir
#
#         Elige tu opción: 5
#     Tienes que escribir un número del 1 al 4.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Publicar un mensaje de estado
#         4. Salir
#
#         Elige tu opción: 4
#     ¡Hasta pronto!
#
# Recuerda: ordena y comenta profusamente tu programa, ahora empieza a ser clave que cada parte del programa esté bien diferenciada de las demás, porque muchas se parecen y podemos liarnos. Además, son programas grandes y hay claramente una parte de datos y otra de ejecución.
