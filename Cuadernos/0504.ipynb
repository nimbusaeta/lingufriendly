# %% [markdown]
# # Ejercicio final del tema 5 - Red social
#
# Hasta ahora, toda la información del perfil del usuario venía de su parte, directamente o a través de cálculos que hacíamos con información aportada por él. En este ejercicio vamos a completar la información de perfil con datos que obtenemos de otras fuentes.
#
# Modifica el programa del tema anterior para que esta vez:
# - Pregunte, cada vez que el usuario quiera rellenar o actualizar sus datos, por la provincia en la que vive y la transforme a todo minúsculas, para que pueda escribirla como quiera.
# - Compruebe si la provincia está en alguna de las listas de provincias que te proporcionamos más abajo.
#     - Si está en alguna lista, debe guardar el dato de la comunidad autónoma a la que pertenece.
#     - Si no está en ninguna lista, no crea el dato de la comunidad autónoma.
# - Debe imprimir, en mayúsculas, el dato de la provincia, así como el de la comunidad autónoma, si lo hay, cuando imprime los datos del perfil.
#
# Aquí tienes los datos que necesitas para España, pero puedes hacerlo con cualquier país. Fíjate en que las provincias están dadas en minúsculas para que puedas compararlas con lo que ponga el usuario transformado a minúsculas; de esta forma, el usuario puede introducir la provincia de cualquier forma, mientras las tildes estén bien puestas.

# %%
# Listas de provincias españolas por comunidad autónoma

andalucia = [
"almería",
"cádiz",
"córdoba",
"granada",
"huelva",
"jaén",
"málaga",
"sevilla"
]

aragon = [
"huesca",
"zaragoza",
"teruel"
]

asturias = ["asturias"]

baleares = ["islas baleares"]

canarias = [
"santa cruz de tenerife",
"las palmas"
]

cantabria = ["santander"]

castillalamancha = [
"albacete",
"ciudad Real",
"cuenca",
"guadalajara",
"toledo"
]

castillaleon = [
"ávila",
"burgos",
"león",
"palencia",
"salamanca",
"segovia",
"soria",
"valladolid",
"zamora"
]

cataluña = [
"barcelona",
"girona",
"lleida",
"tarragona"
]

comunidadvalenciana = [
"alicante",
"castellón",
"valencia"
]

extremadura = [
"badajoz",
"cáceres"
]

galicia = [
"a coruña",
"lugo",
"ourense",
"pontevedra"
]

larioja = ["la rioja"]

madrid = ["madrid"]

murcia = ["murcia"]

navarra = ["navarra"]

paisvasco = [
"álava",
"guipúzcoa",
"vizcaya"
]

# %% [markdown]
# Este es el output esperado para el ejercicio, para el caso en que el usuario quiera crear un perfil nuevo desde el principio:
#
#     ¿Quieres crear un perfil nuevo? (responde sí o no): s
#     ¿Cómo te llamas?: federico
#     ¿Cuál es tu primer apellido?: garcía
#     ¿Y el segundo?: lorca
#     ¿Cuál es tu año de nacimiento?: 1898
#     ¿En qué provincia vives? granada
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 168
#
#     Tu perfil ha sido creado.
#     Nombre: Federico García Lorca
#     Edad: 122 años
#     Provincia: Granada
#     Comunidad Autónoma: Andalucía
#     Estatura: 1.68 metros
