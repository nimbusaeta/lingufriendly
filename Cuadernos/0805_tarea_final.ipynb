# %% [markdown]
# # Ejercicio final del tema 8 - Red social
# Hasta ahora, los datos del usuario no se guardaban en ningún sitio. Ya nos pidiera el usuario crear o modificar perfiles, hacíamos prácticamente lo mismo: imprimir los datos por pantalla. Pero ahora sabemos cómo gestionar datos entre una sesión y otra.
#
# Además, hemos aprendido a hacer nuestros programas principales mucho más cortos, gracias a los módulos.
#
# Modifica el programa del tema anterior, para que:
# - La función `crear_perfil()` pregunte el nombre al usuario y, justo a continuación, busque (con la función `os.path.isfile()`) si existe el fichero correspondiente a ese usuario.
#     - Si existe, devolverá un mensaje tipo `Ya existe un perfil con ese nombre` y volverá al menú principal.
#     - Si no existe, preguntará por el resto de datos al usuario para hacer su perfil. Además, guardará estos datos, ya procesados (es decir, corregidos los apellidos, calculada la edad y la altura en metros, y hallada la comunidad autónoma a partir de la provincia) en un fichero (basta con abrirlo en modo `w`). El fichero tomará el nombre del nombre del usuario, y la extensión será `.user`. Para ello, tendrás que escribir una nueva función `guardar_datos()` que reciba los datos de `pedir_datos()` y los escriba en un fichero, cada dato en una línea.
# - La función `modificar_perfil()` pregunte el nombre al usuario y, justo a continuación, busque si existe el fichero correspondiente a ese usuario.
#     - Si no existe, devolverá un mensaje tipo `No existe ningún perfil con ese nombre` y volverá al menú principal.
#     - Si existe, preguntará por el resto de datos al usuario para sobreescribirlos en el fichero (basta con abrirlo en modo `w`).
# - La función `publicar_mensaje()` pregunte el nombre al usuario y, justo a continuación, busque si existe el fichero correspondiente a ese usuario.
#     - Si no existe, devolverá un mensaje tipo `No existe ningún perfil con ese nombre` y volverá al menú principal.
#     - Si existe, preguntará el mensaje al usuario para añadirlo al fichero correspondiente (basta con abrirlo en modo `a`).
# - Exista una nueva opción en la función `preguntar_opcion()`, «Ver mi perfil», que será la número 3. Por consiguiente, tendrás que escribir una nueva función `consultar_perfil()`, que pregunte el nombre al usuario y, justo a continuación, busque si existe el fichero correspondiente a ese usuario.
#     - Si no existe, devolverá un mensaje tipo `No existe ningún perfil con ese nombre` y volverá al menú principal.
#     - Si existe, leerá el fichero e imprimirá el perfil del usuario teniendo en cuenta que cada dato está en una línea diferente (tendrás que abrirlo en modo `r`). Además, deberás crear la siguiente condición: si el fichero tiene más de 7 líneas, deberá imprimir la string `Mensajes` y, debajo, todas las líneas restantes, desde la 8 hasta la última.
# - Las funciones estén separadas en un módulo `redsocial.py` y el programa principal se encuentre en un archivo .py o .ipynb, en el que se importen esas funciones. El programa principal será el siguiente:
#
#
#     from redsocial import preguntar_opcion, crear_perfil, modificar_perfil, consultar_perfil, publicar_mensaje
#
#     continuar = True
#     while continuar:
#         decision = preguntar_opcion()
#         if decision == 1:
#             crear_perfil()
#         elif decision == 2:
#             modificar_perfil()
#         elif decision == 3:
#             consultar_perfil()
#         elif decision == 4:
#             publicar_mensaje()
#         elif decision == 5:
#             print("¡Hasta pronto!")
#             continuar = False # cerramos el bucle
#         # Fallback
#         else:
#             print("Tienes que escribir un número del 1 al 5.")

# %% [markdown]
# Esta es la salida esperada para el código:
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 1
#     ¿Cómo te llamas?: JUANA
#     ¿Cuál es tu primer apellido?: asbaje
#     ¿Y el segundo?: ramírez
#     ¿Cuál es tu año de nacimiento?: 1648
#     ¿En qué provincia vives?: logroño
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 161
#
#     Tu perfil ha sido creado.
#
#     Nombre: Juana Asbaje Ramírez
#     Edad: 374 años
#     Provincia: Logroño
#     Comunidad: La Rioja
#     Estatura: 1.61 metros
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 2
#     ¿Cómo te llamas?: JUANA
#     ¿Cuál es tu primer apellido?: asbaje
#     ¿Y el segundo?: ramírez
#     ¿Cuál es tu año de nacimiento?: 1648
#     ¿En qué provincia vives?: Tepetlixpa
#     Y para acabar, ¿cuál es tu estatura? (en centímetros): 161
#
#     Tu perfil ha sido actualizado.
#
#     Nombre: Juana Asbaje Ramírez
#     Edad: 374 años
#     Provincia: Tepetlixpa
#     Comunidad:
#     Estatura: 1.61 metros
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 4
#     ¿Cómo te llamas?: juana
#     ¿Qué estás pensando?: Yo no estimo tesoros ni riquezas; y así, siempre me causa más contento poner riquezas en mi pensamiento que no mi pensamiento en las riquezas.
#
#     Juana dice: Yo no estimo tesoros ni riquezas; y así, siempre me causa más contento poner riquezas en mi pensamiento que no mi pensamiento en las riquezas.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 3
#     ¿Cómo te llamas?: juana
#     Tu perfil
#     Nombre: Juana Asbaje Ramírez
#     Edad: 374 años
#     Provincia: Tepetlixpa
#     Comunidad:
#     Estatura: 1.61 metros
#
#     Mensajes:
#     Yo no estimo tesoros ni riquezas; y así, siempre me causa más contento poner riquezas en mi pensamiento que no mi pensamiento en las riquezas.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 1
#     ¿Cómo te llamas?: juana
#
#     Ya existe un usuario con ese nombre.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 2
#     ¿Cómo te llamas?: Asbaje Ramírez
#
#     No existe ningún perfil con ese nombre.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 3
#     ¿Cómo te llamas?: Asbaje Ramírez
#
#     No existe ningún perfil con ese nombre.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 4
#     ¿Cómo te llamas?: Asbaje Ramírez
#
#     No existe ningún perfil con ese nombre.
#
#
#         MENÚ
#         1. Rellenar perfil de usuario
#         2. Modificar mis datos
#         3. Ver mi perfil
#         4. Publicar un mensaje de estado
#         5. Salir
#
#         Elige tu opción: 5
#     ¡Hasta pronto!
#
# Además, debe haber creado el fichero `juana.user` con el siguiente contenido:
#
#     Juana
#     Asbaje
#     Ramírez
#     161
#     Tepetlixpa
#
#     1.61
#     Yo no estimo tesoros ni riquezas; y así, siempre me causa más contento poner riquezas en mi pensamiento que no mi pensamiento en las riquezas.

# %% [markdown]
# **Bonus track** (solo si te apetece hacerlo):
#
# Para practicar un poco más ahora que sabes qué son los módulos, puedes averiguar la edad exacta del usuario importando la librería `datetime`, que es de las que ya vienen instaladas con Python ([documentación de `datetime` en inglés](https://docs.python.org/3/library/datetime.html)), para no tener que cambiar el código cuando cambie el día.
#
# Tendrás que preguntarle al usuario, además del año, el mes y el día. Mi recomendación es que definas una función `calcular_edad()` a la que le pasarás esos tres datos. En ella, tendrás que acceder a `date.today()` y comparar los datos del usuario con `date.today().year`, `date.today().month` y `date.today().day`: si el mes de nacimiento es menor que el actual, comparamos los días. Y, sin salir de ese supuesto, si el día de nacimiento es menor que el actual, entonces para calcular la edad solo tenemos que restar el año de nacimiento del año actual. Si es mayor, le restamos 1 a ese cálculo (porque la persona no ha cumplido los años todavía). Si el mes de nacimiento es mayor, también tenemos que calcular la edad restando 1 al año actual menos el año de nacimiento.
#
# Por último, si quieres felicitar al usuario cuando sea su cumpleaños, solo tienes que imprimir el mensaje que quieras cuando coincidan tanto el mes como el día.
